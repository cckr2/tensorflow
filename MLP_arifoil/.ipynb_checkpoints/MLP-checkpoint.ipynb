# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt

number_of_hidden = 10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d0cbc300c2c4> in <module>()
# ----> 1 import tensorflow as tf
#       2 import numpy
#       3 import matplotlib.pyplot as plt
#       4
#       5 number_of_hidden = 10
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *
#      25 # pylint: enable=wildcard-import
#      26
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\__init__.py in <module>()
#      70
#      71 # Ops
# ---> 72 from tensorflow.python.ops.standard_ops import *
#      73
#      74 # Namespaces
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\ops\standard_ops.py in <module>()
#      30 from tensorflow.python.ops import spectral_grad
#      31 from tensorflow.python.ops import state_grad
# ---> 32 from tensorflow.python.ops import tensor_array_grad
#      33 from tensorflow.python.util.all_util import remove_undocumented
#      34
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\ops\tensor_array_grad.py in <module>()
#      23 # TODO(b/31222613): These ops may be differentiable, and there may be
#      24 # latent bugs here.
# ---> 25 ops.NotDifferentiable("TensorArray")
#      26 ops.NotDifferentiable("TensorArrayGrad")
#      27 ops.NotDifferentiable("TensorArraySize")
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py in NotDifferentiable(op_type)
#    2288   if not isinstance(op_type, six.string_types):
#    2289     raise TypeError("op_type must be a string")
# -> 2290   _gradient_registry.register(None, op_type)
#    2291
#    2292
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\registry.py in register(self, candidate, name)
#      60       raise KeyError("Registering two %s with name '%s' !"
#      61                      "(Previous registration was in %s %s:%d)" %
# ---> 62                      (self._name, name, function_name, filename, line_number))
#      63
#      64     logging.vlog(1, "Registering %s (%s) in %s.", name, candidate, self._name)
#
# KeyError: "Registering two gradient with name 'TensorArray' !(Previous registration was in <module> C:\\Anaconda\\envs\\tensorflow\\lib\\site-packages\\ipykernel_launcher.py:16)"

# %%
#Load Data
data_file_name = 'data_Alpha_0.txt'  
xy= numpy.loadtxt(data_file_name, unpack=True, dtype='float32')

temp_x =  xy[1:-1]  
temp_y =  xy[-1]
print (temp_x)

x_data = np.reshape(temp_x, [1,-1])
y_data = np.reshape(temp_y, [1,-1])

X = tf.placeholder(dtype=tf.float32, shape=[1,None])
Y = tf.placeholder(dtype=tf.float32, shape=[1,None])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-1f26b2b3d064> in <module>()
#       1 #Load Data
#       2 data_file_name = 'data_Alpha_0.txt'
# ----> 3 xy= numpy.loadtxt(data_file_name, unpack=True, dtype='float32')
#       4
#       5 temp_x =  xy[1:-1]
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     915             fname = str(fname)
#     916         if _is_string_like(fname):
# --> 917             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     918             fencoding = getattr(fh, 'encoding', 'latin1')
#     919             fh = iter(fh)
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     258
#     259     ds = DataSource(destpath)
# --> 260     return ds.open(path, mode, encoding=encoding, newline=newline)
#     261
#     262
#
# C:\Anaconda\envs\tensorflow\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     614                                       encoding=encoding, newline=newline)
#     615         else:
# --> 616             raise IOError("%s not found." % path)
#     617
#     618
#
# OSError: data_Alpha_0.txt not found.

# %%
# setup hidden layer
W1 = tf.Variable(tf.random_normal([number_of_hidden, 1]))
b1 = tf.Variable(tf.random_normal([number_of_hidden, 1]))
layer1_out = tf.nn.sigmoid(tf.matmul(W1, X ) + b1)

# setup output layer
W2 = tf.Variable(tf.random_normal([1,number_of_hidden]))
b2 = tf.Variable(tf.random_normal([1,1]))
y_out = tf.matmul(W2,layer1_out) + b2

# %%
# setup cost
cost = tf.nn.l2_loss(y_out-Y)

# setup optimizer
optimizer= tf.train.AdamOptimizer(0.1)
do_train = optimizer.minimize(cost)

# %%
init = tf.global_variables_initializer()

with tf.Session() as sess:
  sess.run(init)
  for i in range(5000):
    sess.run(do_train,feed_dict={X: x_data, Y: y_data})
  # generate test data
  x_temp =  np.linspace(0, 20, 50)
  x_test = [x_temp]
  y_test = sess.run(y_out,feed_dict={X: x_test})

# 그래프 그리기
plt.plot(x_data,y_data,'ro',alpha=0.05)
plt.plot(x_test,y_test,'b^',alpha=1)
plt.show()
